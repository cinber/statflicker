# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df_league = pd.read_csv('points.csv')
div1 = pd.read_csv('div1.csv')
div2 = pd.read_csv('div2.csv')

# import point-data player
scc = pd.read_csv('points-scc.csv')
kev = pd.read_csv('points-kev.csv')
lazn = pd.read_csv('points-lazn.csv')
janis = pd.read_csv('points-janis.csv')
ct = pd.read_csv('points-ct.csv')
maxi = pd.read_csv('points-max.csv')

# %%
print(df_league.head(10))
# Out:
#    team_id  manager_id manager_name              team  season  week  \
# 0   129856     1022477  AsbachUralt  Mein Gott Walter      20     1
# 1   129856     1022477  AsbachUralt  Mein Gott Walter      20     1
# 2   129856     1022477  AsbachUralt  Mein Gott Walter      20     1
# 3   129856     1022477  AsbachUralt  Mein Gott Walter      20     1
# 4   129856     1022477  AsbachUralt  Mein Gott Walter      20     1
# 5   129856     1022477  AsbachUralt  Mein Gott Walter      20     1
# 6   129856     1022477  AsbachUralt  Mein Gott Walter      20     1
# 7   129856     1022477  AsbachUralt  Mein Gott Walter      20     1
# 8   129856     1022477  AsbachUralt  Mein Gott Walter      20     1
# 9   129856     1022477  AsbachUralt  Mein Gott Walter      20     1
#
#       player_name  player_id            team.1 position set_pos  points
# 0  Brandon Ingram       1459  Mein Gott Walter     PG/F     ANY    76.3
# 1     Dario Saric       1139  Mein Gott Walter        F      BN    35.5
# 2  Derrick Favors        632  Mein Gott Walter     PF/C    PF/C    27.0
# 3  Dewayne Dedmon       1096  Mein Gott Walter        C      BN    18.8
# 4   Evan Fournier        907  Mein Gott Walter    SG/SF      BN    43.5
# 5       Ja Morant       1883  Mein Gott Walter       PG     ANY    45.2
# 6    Jamal Murray       1445  Mein Gott Walter        G       G    53.2
# 7  Jonathan Isaac       1562  Mein Gott Walter        F   SG/SF    28.0
# 8      Kevin Knox       1683  Mein Gott Walter        F      PF    31.7
# 9    Kyrie Irving        754  Mein Gott Walter       PG      PG    92.5

# %%
player = df_league['manager_name']
print(player)
# Out:
# 0      AsbachUralt
# 1      AsbachUralt
# 2      AsbachUralt
# 3      AsbachUralt
# 4      AsbachUralt
#           ...
# 619       ManuGino
# 620       ManuGino
# 621       ManuGino
# 622       ManuGino
# 623       ManuGino
# Name: manager_name, Length: 624, dtype: object

# %%
# points = []
# players = []
# week = ['1','2','3','4']

# for player in df['player_name']:
#     players.append(player)
# for point in df['points']:
#     points.append(point)

# print(players) 
# print(points)

# %%
sns.catplot(x='week', y="points", hue="manager_name", data=df_league, kind="swarm")

# %%
sns.catplot(x='week', y="points", hue="manager_name", data=div1, kind="swarm")
# plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
sns.catplot(x='week', y="points", hue="manager_name", data=div2, kind="swarm")
# plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
sns.lineplot(x="week", y="points", hue="manager_name", data=div1)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
sns.lineplot(x="week", y="points", hue="manager_name", data=div2)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
sns.catplot(x='week', y="points", hue="player_name", data=scc, kind="swarm")
# plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
sns.catplot(x='week', y="points", hue="player_name", data=kev, kind="swarm")

# %%
sns.catplot(x='week', y="points", hue="player_name", data=janis, kind="swarm")

# %%
sns.catplot(x='week', y="points", hue="player_name", data=ct, kind="swarm")

# %%
sns.catplot(x='week', y="points", hue="player_name", data=lazn, kind="swarm")

# %%
sns.catplot(x='week', y="points", hue="player_name", data=maxi, kind="swarm")
